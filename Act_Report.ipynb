# %% [markdown]
# # Analyzing and Visualizing Data
#
# Data analyszing is the next step taken after data cleaning. This is done to provide meaningful insights to the WeRateDogs dataset

# %% [markdown]
# ### What is the most popular tweet source?

# %% [markdown]
# ![twitter%20source.PNG](attachment:twitter%20source.PNG)

# %% [markdown]
# From the analysis above, it is shown that there are four major tweet sources which are `Twitter for Iphone`, `Vine - Make a Scene`, `Twitter Web Client`and `TweetDeck`. It also shows that over 90% users make use of 'Twitter for Iphone' with the value of 2191 users while less than 10% of users comprises of the other tweet sources 134 users.

# %% [markdown]
# ### What is the most popular dog breed and the least popular dog breed?

# %% [markdown]
# ![pop%20dog%20breed.PNG](attachment:pop%20dog%20breed.PNG)

# %% [markdown]
# ![least%20pop%20breed.PNG](attachment:least%20pop%20breed.PNG)

# %% [markdown]
# The popular dog breed in this dataset is **golden_retriever** follwed closely by **labrador_retriever**, **pembroke**, **chihuahua**. While the least dog breed by popularity are **irish_wolfhound**, **silky_terrier**, **bouvier_des_flandres** among others

# %% [markdown]
# ### What is the correlation between favorite_counts and retweets

# %% [markdown]
# ![corr.PNG](attachment:corr.PNG)

# %% [markdown]
# From the graph above, it shows that there is a positive correlation (0.801537359129741) between the number of favorite_counts and retweet. Each post made is likely to reach a wider audence by the number of likes and retweets. Though the proportion of favoutrit count is highr than that of the retweets.

# %% [markdown]
# ### What is most popular dog name?

# %% [markdown]
# ![dog%20name.PNG](attachment:dog%20name.PNG)

# %% [markdown]
# The above analysis shows that **charlie**, **cooper**, **oliver** are the most popular dog name

# %% [markdown]
# ### What breed has the highest rating?

# %% [markdown]
# ![rating.PNG](attachment:rating.PNG)

# %% [markdown]
# This analysis, shows that **soft-coated_wheaten_terrier**, is the breed with the average highest rating.

# %% [markdown]
# ### What is the average retweeted and least retweeted dog breed?

# %% [markdown]
# ![most%20ret.PNG](attachment:most%20ret.PNG)

# %% [markdown]
# ![least%20ret.PNG](attachment:least%20ret.PNG)

# %% [markdown]
# The bar chart above shows that, the top averge retweeted dog breeds are the **standard_poodle**, **bedlington_terrier**, **afghan_hound**, **french_bulldog** while the least retweeted dog breeds are **groenendael**, **brabancon_griffon**, **japanese_spaniel**

# %% [markdown]
# ### What is the average liked dog breed?

# %% [markdown]
# ![avg%20fav%20count.PNG](attachment:avg%20fav%20count.PNG)

# %% [markdown]
# **bedlington_terrier**, **saluki**, **french_bulldog** are the breeds with the highest average favorite_counts

# %% [markdown]
# ### What is the top dog stages

# %% [markdown]
# ![dog%20stage.PNG](attachment:dog%20stage.PNG)

# %% [markdown]
# From the above analysis, it shows that **pupper** is the most common dog stage
