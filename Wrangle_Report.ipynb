# %% [markdown]
# # Data Wrangling Process

# %% [markdown]
# The following steps were taken to perform this analysis in project. This processes would be futher explained below
# - Importing
# - Data Gathering
# - Data Accessing
# - Data Cleaning
# - Storing Cleaned Data
# - Exploratory Data Analysis
# - Conclusion

# %% [markdown]
# ### Importing
# The first step taken was to import the necessary python libraries used in this project.

# %% [markdown]
# ### Data Gathering
#
# The first dataset `twitter-archive-enhanced.csv` was given to me by the instructors at Udacity which I downloaded to my local desktop and was extracted manually using **pd.read_csv** and was saved as `twitter_achived`.
#
# The secong dataset `image-predictions.tsv`was also given to me by Udacity instructors and was specifically instructed to download the file programmatically by using a python library called **request** which was done and I saved the file as `image_prediction`.
#
# The third dataset to be gathered or extracted is by using the twiiter API, which required me to apply for twitter developers account. I got my twitter API keys from the twitter developer account .This dataset is be extracted using another python library called **tweepy**.
# The data was extracted by querying the twitter API and saved into a JSON file which was then turned into a dataframe. This dataframe was then accessed.

# %% [markdown]
# ### Data Accessing
#
# I accessed the extracted data in 2 ways which are
# - Visual Accessment: Displaying the extracted data by using the `head()`, `Tail()` functions and
# - Programmatic Accessment: Using the `info()` function
#
# After accessing, I was able to identify some quality and tidiness issues which will be listed in the data cleaning section with the possible solution done

# %% [markdown]
# ### Data Cleaning
#
# Firstly, I made a copy of each datasets. After merging and cleaning my dataset, I also made a copy of my merged dataset
#
# ![quality-2.PNG](attachment:quality-2.PNG)

# %% [markdown]
# ![tidiness-2.PNG](attachment:tidiness-2.PNG)

# %% [markdown]
# ### Storing Data
#
#
# After cleaning my data, I stored my data in a csv file which was later used for exploratory data analysis

# %% [markdown]
# ### Conclusion

# %% [markdown]
# From the analysis above, we can conlude that:
#
# - `Twitter for Iphone` is the most popular tweet source
# - The golden retriever breed is the most popular dog breed while irish_wolfhoundis the leave popular dog breed among others
# - There is a positive correlation between favorite_counts and retweets
# - charlie, cooper, oliver are the most common names
# - soft-coated_wheaten_terrier is the breed with highest average rating
# - standard_poodle is the top average retweeted dog breed while groenendael is the least average retweeted dog breed
# - bedlington_terrier is the breeds with the highest average favorite_counts
# - pupper is the most common dog stage
